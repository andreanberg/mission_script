# %%
# Turn off Jupyter output caching
# %config InteractiveShell.cache_size = 0

# %%
# Necessary import
import numpy as np
from drone import Drone
from environment import Env
from simulator import Sim, Takeoff
from debug import Debugger

# %%
# Init necessary objects for simulation
drone = Drone(
    mass=6.0,
    wing_area=0.9,
    thrust=50.0,
)
env = Env(air_density=1.225)
sim = Sim(drone=drone, env=env, dt=0.01)

# Take-off simulation with debugger
args = [
    "pos",  # (2,) - plottable
    ("t", "battery_wh"),  # (2,) - plottable
    # ("pos", "v_body") # (2,2)
    # plottable with vector TODO perhaps every 100th
]
debug = Debugger(args=args)
sim.run(Takeoff(runway_length=20, debugger=debug))
debug.show_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 13
#       7 args = [
#       8     "pos",  # (2,) - plottable
#       9     ("t", "battery_wh"),  # (2,) - plottable
#      10     #("t", "v_body") # (1,2) - plottable with vector TODO perhaps every 100th dt
#      11 ]
#      12 debug = Debugger(args=args)
# ---> 13 sim.run(Takeoff(runway_length=20, debugger=debug))
#      14 debug.show_data()
#
# File ~/Documents/AERO/mission_script/core/simulator.py:16, in Sim.run(self, mission)
#      15 def run(self, mission):
# ---> 16     mission.run(self)
#
# File ~/Documents/AERO/mission_script/core/simulator.py:46, in Mission.run(self, sim)
#      44 self.on_start(sim)
#      45 drone = sim.drone
# ---> 46 self.log(drone)
#      47 while self.simulate_condition(sim):
#      48     force_vec = drone.compute_forces(sim.env.rho)
#
# File ~/Documents/AERO/mission_script/core/simulator.py:41, in Mission.log(self, drone)
#      39 def log(self, drone: Drone):
#      40     if self.debugger != None:
# ---> 41         self.debugger.get_data(drone)
#
# File ~/Documents/AERO/mission_script/core/debug.py:20, in Debugger.get_data(self, drone)
#      18         names.add(key[1])
#      19     else:
# ---> 20         raise ValueError(f'Key "{key}" incorrect shape')
#      22 timedict = {name: drone.__dict__[name] for name in names}
#      23 self.data.append(timedict)
#
# ValueError: Key "pos" incorrect shape

# %%
# drone.debug = True
# cl = sim.run(Climb(climb_angle=15, target_altitude=10))

## TODO något script sådant att man kan se live med
# en plot som dynamiskt växer medan scriptet körs
# fixa problemet med var du är

print(f"Climb finished: \n{drone.t:.1f}\n")
print(f"pos \n{np.round(drone.pos,3)}\n")
print(f"v \n{np.linalg.norm(drone.v_body):.2f} m/s\n")
print(f"climbed \n{drone.climbed}\n")
# Out:
# Climb finished:
# 1.4
#
# pos
# [7.96 0.  ]
#
# v
# 11.17 m/s
#
# climbed
# False
